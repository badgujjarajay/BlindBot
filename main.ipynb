# %%
import cv2
from Image_Captioning import generate_caption
from Object_Detection import object_detector
from Text_to_Speech import tts

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('Test_Data/Test1.jpg')

# %%
desc = generate_caption.get_desc('Test_Data/Test1.jpg')

# %%
print(desc)
# Out:
# two dogs are running through the grass

# %%
objects, position, image = object_detector.detect_objects(img)

# %%
print(objects)
print(position)
# Out:
# ['dog', 'dog', 'frisbee']
# ['left', 'right', 'front']

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F2B53D1CAD0>

# %%
tts.speak(desc, objects, position)
# Out:
# two dogs are running through the grass
#  There is a dog to your left
#  There is a dog to your right
#  There is a frisbee to your front

# %%
img = cv2.imread('Test_Data/Test2.jpg')

# %%
desc = generate_caption.get_desc('Test_Data/Test2.jpg')
print(desc)
# Out:
# man in red shirt is standing in front of the street

# %%
objects, position, image = object_detector.detect_objects(img)

# %%
print(objects)
print(position)
# Out:
# ['person']
# ['right']

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F2B681BC190>

# %%
tts.speak(desc, objects, position)
# Out:
# man in red shirt is standing in front of the street
#  There is a person to your right
